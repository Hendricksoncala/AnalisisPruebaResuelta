# %% [markdown]
# <a href="https://colab.research.google.com/github/Hendricksoncala/AnalisisPruebaResuelta/blob/main/clase_1_IF_ELSE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
trabajador = ""
sueldo = 0.0
aumento = 0.0

Sueldo_Trabajador = float(input("ingrese el sueldo de "))
def sueldo_final():
  if Sueldo_Trabajador <= 1000:
    aumento = sueldo * 0.15
    sueldo = aumento + sueldo
    print(f"Tu nuevo sueldo es {sueldo}");
  elif Sueldo_Trabajador > 1000:
    aumento = sueldo * 0.12
    sueldo = aumento + sueldo
    print(f"Tu nuevo sueldo es {sueldo}")

print(sueldo_final())


def sueldo_final(sueldo):
    if sueldo <= 1000:
        aumento = sueldo * 0.15
    else:
        aumento = sueldo * 0.12

    sueldo = sueldo + aumento
    print(f"Tu nuevo sueldo es {sueldo}")

sueldo_final(sueldo)
# Out:
# ingrese el sueldo de 1020
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipykernel_279/4152440630.py in <cell line: 0>()
#      14     print(f"Tu nuevo sueldo es {sueldo}")
#      15
# ---> 16 print(sueldo_final())
#
# /tmp/ipykernel_279/4152440630.py in sueldo_final()
#       5 Sueldo_Trabajador = float(input("ingrese el sueldo de "))
#       6 def sueldo_final():
# ----> 7   if sueldo <= 1000:
#       8     aumento = sueldo * 0.15
#       9     sueldo = aumento + sueldo
#
# UnboundLocalError: cannot access local variable 'sueldo' where it is not associated with a value

# %% [markdown]
# ##1. Estructura if/else
# son estructuras que evaluan una condicion. Da un resultado booleando (True o False)
#
# sinstaxis de si/no
# ```
# if condicon:
#  codigo a ejecutar si la condicion es verdadera
# else:
#   codigo a ejecutar si la condicion es falsa
